# %%
from data.transform import (
    volume_transform,
    # slice_transform_train,
    # slice_transform_valid,
    # FilterSliced,
)
from glob import glob
import os
from monai.transforms.utils import generate_spatial_bounding_box
import os
import numpy as np
import torch
import nibabel as nib
from monai.transforms import Compose, LoadImaged, Spacingd  # for example
from torch.utils.data import Dataset

# %%
import os
import numpy as np
import nibabel as nib
import torch


def process_and_save_slices(
    path_dicts,
    volume_transform,
    samples_per_image=12,
    output_dir="sliced_output",
    source_key="label",  # which key to use for bounding-box
):
    """
    1) For each (image, label) file in `path_dicts`, load & preprocess them in 3D.
    2) Find the non-zero bounding box based on `source_key` (e.g. label).
    3) Randomly pick `samples_per_image` slice indices within that bounding box's D-range.
    4) Extract and (optionally) transform each 2D slice, then save as a separate NIfTI.
    """
    os.makedirs(output_dir, exist_ok=True)

    for subj_idx, data_dict in enumerate(path_dicts):
        # ---------------------------------------------------------
        # 1) Load & apply 3D transforms (e.g. LoadImaged, Spacingd, etc.)
        # ---------------------------------------------------------
        # img_nii = nib.load(data_dict['image'])
        # print(img_nii.shape) #(512, 512, 275)
        processed_3d = volume_transform(data_dict)
        img_3d = processed_3d["image"]  
        lbl_3d = processed_3d["label"]
        # print(img_3d.shape)  shape assumed [1, 380, 380, 275])

        # ---------------------------------------------------------
        # 2) Find bounding box from the `source_key`, usually "label"
        #    box_start, box_end are each [d_start, h_start, w_start].
        # ---------------------------------------------------------
        vol_for_bbox = processed_3d[source_key]
        box_start, box_end = generate_spatial_bounding_box(vol_for_bbox)

        # box_start[-1] / box_end[-1] is W,
        # box_start[-2] / box_end[-2] is H,
        # box_start[-3] / box_end[-3] is D if shape is [C, D, H, W]
        depth_min, depth_max = box_start[0], box_end[0]  # bounding box along the D dimension

        if depth_min >= depth_max:
            # If bounding box is invalid or empty, skip
            print(f"No non-zero region found for subject {subj_idx}, skipping.")
            continue
        # ---------------------------------------------------------
        # 3) Randomly pick `samples_per_image` slices from [depth_min, depth_max)
        # ---------------------------------------------------------
        slice_idx = torch.randint(depth_min, depth_max, (samples_per_image,))

        # ---------------------------------------------------------
        # 4) Loop over the chosen slice indices, extract 2D slices, apply optional slice_transform, then save
        # ---------------------------------------------------------
        for _, d_idx in enumerate(slice_idx):
            slice_image = img_3d[:, d_idx].clone()  # shape [C, H, W]
            slice_label = lbl_3d[:, d_idx].clone()

            # Convert to numpy for saving
            slice_image_np = slice_image.cpu().numpy()
            slice_label_np = slice_label.cpu().numpy()

            # Often channel dimension is [C=1, H, W], so remove channel if desired
            if slice_image_np.shape[0] == 1:
                slice_image_np = slice_image_np[0]
            if slice_label_np.shape[0] == 1:
                slice_label_np = slice_label_np[0]

            # Build file names
            out_img_name = f"subject_{subj_idx}_slice_{d_idx}_img.nii.gz"
            out_lbl_name = f"subject_{subj_idx}_slice_{d_idx}_lbl.nii.gz"
            out_img_path = os.path.join(output_dir, out_img_name)
            out_lbl_path = os.path.join(output_dir, out_lbl_name)

            # Save NIfTI
            nib.save(nib.Nifti1Image(slice_image_np, affine=np.eye(4)), out_img_path)
            nib.save(nib.Nifti1Image(slice_label_np, affine=np.eye(4)), out_lbl_path)

            print(f"Saved: {out_img_path}, {out_lbl_path}")

# %%
import torch
from monai.data.meta_obj import get_track_meta
from monai.transforms.utils import generate_spatial_bounding_box
from monai.utils.type_conversion import convert_data_type, convert_to_tensor
from monai.transforms import (
    Compose,
    RandAffined,
    RandGaussianNoised,
    MapTransform,
    ToTensord,
    LoadImaged,
    Orientationd,
    CenterSpatialCropd,
    Resized,
    NormalizeIntensityd,
    Spacingd,
    Rand2DElasticd,
)

slice_transform_train = Compose(
    [
        LoadImaged(keys=["image", "label"], image_only=False, ensure_channel_first=True),
        Resized(
            keys=["image", "label"],
            spatial_size=[256, 256],
            mode=("bilinear", "nearest"),
        ),
        RandAffined(
            keys=["image", "label"],
            mode=("bilinear", "nearest"),
            prob=0.5,
            rotate_range=(3.14 / 6, 3.14 / 6),
            scale_range=(0.2, 0.2),
            translate_range=(10, 10),
        ),
        Rand2DElasticd(
            keys=["image", "label"],
            spacing=(20, 20),
            magnitude_range=(1, 2),
            prob=0.5,
            padding_mode="zeros",
            mode=("bilinear", "nearest"),
        ),
        NormalizeIntensityd(keys=["image"]),
        RandGaussianNoised(keys=["image"], prob=0.5, std=0.5),
        ToTensord(keys=["image", "label"]),
    ]
)

slice_transform_valid = Compose(
    [   LoadImaged(keys=["image", "label"], image_only=False, ensure_channel_first=True),
        Resized(
            keys=["image", "label"],
            spatial_size=[192, 192],
            mode=("bilinear", "nearest"),
        ),
        NormalizeIntensityd(keys=["image"]),
        ToTensord(keys=["image", "label"]),
    ]
)

# %%
# Suppose you have something like:
image_set = 'train'
file_paths = glob(os.path.join(r'C:\Users\SongL\Desktop\BayeSeg\dataset\ImageCAS', image_set, "*.nii.gz"))
image_paths, label_paths = [], []
for path in file_paths:
    if path.split("\\")[-1][9:12] in ["seg", "Seg"]:
        label_paths.append(path)
    else:
        image_paths.append(path)

image_paths, label_paths = sorted(image_paths), sorted(label_paths)

path_dicts = [
    {"image": image_path, "label": label_path}
    for image_path, label_path in zip(image_paths, label_paths)
]

# %%
process_and_save_slices(
    path_dicts,
    volume_transform=volume_transform, 
    samples_per_image=12,
    output_dir= os.path.join("E:\sliced_output",image_set),
)
# Out:
# c:\Users\SongL\anaconda3\envs\BayeSeg\lib\site-packages\monai\utils\deprecate_utils.py:321: FutureWarning: monai.transforms.utils generate_spatial_bounding_box:allow_smaller: Current default value of argument `allow_smaller=True` has been deprecated since version 1.2. It will be changed to `allow_smaller=False` in version 1.5.
#   warn_deprecated(argname, msg, warning_category)
# Saved: E:\sliced_output\train\subject_0_slice_78_img.nii.gz, E:\sliced_output\train\subject_0_slice_78_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_0_slice_265_img.nii.gz, E:\sliced_output\train\subject_0_slice_265_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_0_slice_229_img.nii.gz, E:\sliced_output\train\subject_0_slice_229_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_0_slice_48_img.nii.gz, E:\sliced_output\train\subject_0_slice_48_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_0_slice_227_img.nii.gz, E:\sliced_output\train\subject_0_slice_227_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_0_slice_193_img.nii.gz, E:\sliced_output\train\subject_0_slice_193_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_0_slice_100_img.nii.gz, E:\sliced_output\train\subject_0_slice_100_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_0_slice_115_img.nii.gz, E:\sliced_output\train\subject_0_slice_115_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_0_slice_134_img.nii.gz, E:\sliced_output\train\subject_0_slice_134_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_0_slice_37_img.nii.gz, E:\sliced_output\train\subject_0_slice_37_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_0_slice_179_img.nii.gz, E:\sliced_output\train\subject_0_slice_179_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_0_slice_109_img.nii.gz, E:\sliced_output\train\subject_0_slice_109_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_1_slice_98_img.nii.gz, E:\sliced_output\train\subject_1_slice_98_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_1_slice_183_img.nii.gz, E:\sliced_output\train\subject_1_slice_183_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_1_slice_155_img.nii.gz, E:\sliced_output\train\subject_1_slice_155_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_1_slice_210_img.nii.gz, E:\sliced_output\train\subject_1_slice_210_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_1_slice_7_img.nii.gz, E:\sliced_output\train\subject_1_slice_7_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_1_slice_38_img.nii.gz, E:\sliced_output\train\subject_1_slice_38_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_1_slice_123_img.nii.gz, E:\sliced_output\train\subject_1_slice_123_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_1_slice_120_img.nii.gz, E:\sliced_output\train\subject_1_slice_120_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_1_slice_157_img.nii.gz, E:\sliced_output\train\subject_1_slice_157_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_1_slice_173_img.nii.gz, E:\sliced_output\train\subject_1_slice_173_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_1_slice_11_img.nii.gz, E:\sliced_output\train\subject_1_slice_11_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_1_slice_128_img.nii.gz, E:\sliced_output\train\subject_1_slice_128_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_2_slice_222_img.nii.gz, E:\sliced_output\train\subject_2_slice_222_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_2_slice_51_img.nii.gz, E:\sliced_output\train\subject_2_slice_51_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_2_slice_231_img.nii.gz, E:\sliced_output\train\subject_2_slice_231_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_2_slice_254_img.nii.gz, E:\sliced_output\train\subject_2_slice_254_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_2_slice_49_img.nii.gz, E:\sliced_output\train\subject_2_slice_49_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_2_slice_289_img.nii.gz, E:\sliced_output\train\subject_2_slice_289_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_2_slice_170_img.nii.gz, E:\sliced_output\train\subject_2_slice_170_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_2_slice_74_img.nii.gz, E:\sliced_output\train\subject_2_slice_74_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_2_slice_42_img.nii.gz, E:\sliced_output\train\subject_2_slice_42_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_2_slice_119_img.nii.gz, E:\sliced_output\train\subject_2_slice_119_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_2_slice_150_img.nii.gz, E:\sliced_output\train\subject_2_slice_150_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_2_slice_183_img.nii.gz, E:\sliced_output\train\subject_2_slice_183_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_3_slice_227_img.nii.gz, E:\sliced_output\train\subject_3_slice_227_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_3_slice_265_img.nii.gz, E:\sliced_output\train\subject_3_slice_265_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_3_slice_114_img.nii.gz, E:\sliced_output\train\subject_3_slice_114_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_3_slice_87_img.nii.gz, E:\sliced_output\train\subject_3_slice_87_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_3_slice_112_img.nii.gz, E:\sliced_output\train\subject_3_slice_112_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_3_slice_253_img.nii.gz, E:\sliced_output\train\subject_3_slice_253_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_3_slice_46_img.nii.gz, E:\sliced_output\train\subject_3_slice_46_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_3_slice_224_img.nii.gz, E:\sliced_output\train\subject_3_slice_224_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_3_slice_200_img.nii.gz, E:\sliced_output\train\subject_3_slice_200_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_3_slice_123_img.nii.gz, E:\sliced_output\train\subject_3_slice_123_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_3_slice_167_img.nii.gz, E:\sliced_output\train\subject_3_slice_167_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_3_slice_155_img.nii.gz, E:\sliced_output\train\subject_3_slice_155_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_4_slice_338_img.nii.gz, E:\sliced_output\train\subject_4_slice_338_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_4_slice_169_img.nii.gz, E:\sliced_output\train\subject_4_slice_169_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_4_slice_159_img.nii.gz, E:\sliced_output\train\subject_4_slice_159_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_4_slice_237_img.nii.gz, E:\sliced_output\train\subject_4_slice_237_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_4_slice_292_img.nii.gz, E:\sliced_output\train\subject_4_slice_292_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_4_slice_314_img.nii.gz, E:\sliced_output\train\subject_4_slice_314_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_4_slice_294_img.nii.gz, E:\sliced_output\train\subject_4_slice_294_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_4_slice_306_img.nii.gz, E:\sliced_output\train\subject_4_slice_306_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_4_slice_337_img.nii.gz, E:\sliced_output\train\subject_4_slice_337_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_4_slice_307_img.nii.gz, E:\sliced_output\train\subject_4_slice_307_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_4_slice_250_img.nii.gz, E:\sliced_output\train\subject_4_slice_250_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_4_slice_177_img.nii.gz, E:\sliced_output\train\subject_4_slice_177_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_5_slice_22_img.nii.gz, E:\sliced_output\train\subject_5_slice_22_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_5_slice_137_img.nii.gz, E:\sliced_output\train\subject_5_slice_137_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_5_slice_206_img.nii.gz, E:\sliced_output\train\subject_5_slice_206_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_5_slice_74_img.nii.gz, E:\sliced_output\train\subject_5_slice_74_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_5_slice_238_img.nii.gz, E:\sliced_output\train\subject_5_slice_238_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_5_slice_220_img.nii.gz, E:\sliced_output\train\subject_5_slice_220_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_5_slice_190_img.nii.gz, E:\sliced_output\train\subject_5_slice_190_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_5_slice_214_img.nii.gz, E:\sliced_output\train\subject_5_slice_214_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_5_slice_110_img.nii.gz, E:\sliced_output\train\subject_5_slice_110_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_5_slice_105_img.nii.gz, E:\sliced_output\train\subject_5_slice_105_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_5_slice_246_img.nii.gz, E:\sliced_output\train\subject_5_slice_246_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_5_slice_32_img.nii.gz, E:\sliced_output\train\subject_5_slice_32_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_6_slice_184_img.nii.gz, E:\sliced_output\train\subject_6_slice_184_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_6_slice_225_img.nii.gz, E:\sliced_output\train\subject_6_slice_225_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_6_slice_239_img.nii.gz, E:\sliced_output\train\subject_6_slice_239_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_6_slice_12_img.nii.gz, E:\sliced_output\train\subject_6_slice_12_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_6_slice_33_img.nii.gz, E:\sliced_output\train\subject_6_slice_33_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_6_slice_232_img.nii.gz, E:\sliced_output\train\subject_6_slice_232_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_6_slice_64_img.nii.gz, E:\sliced_output\train\subject_6_slice_64_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_6_slice_113_img.nii.gz, E:\sliced_output\train\subject_6_slice_113_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_6_slice_126_img.nii.gz, E:\sliced_output\train\subject_6_slice_126_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_6_slice_77_img.nii.gz, E:\sliced_output\train\subject_6_slice_77_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_6_slice_72_img.nii.gz, E:\sliced_output\train\subject_6_slice_72_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_6_slice_212_img.nii.gz, E:\sliced_output\train\subject_6_slice_212_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_7_slice_120_img.nii.gz, E:\sliced_output\train\subject_7_slice_120_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_7_slice_282_img.nii.gz, E:\sliced_output\train\subject_7_slice_282_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_7_slice_186_img.nii.gz, E:\sliced_output\train\subject_7_slice_186_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_7_slice_213_img.nii.gz, E:\sliced_output\train\subject_7_slice_213_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_7_slice_263_img.nii.gz, E:\sliced_output\train\subject_7_slice_263_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_7_slice_113_img.nii.gz, E:\sliced_output\train\subject_7_slice_113_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_7_slice_141_img.nii.gz, E:\sliced_output\train\subject_7_slice_141_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_7_slice_190_img.nii.gz, E:\sliced_output\train\subject_7_slice_190_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_7_slice_42_img.nii.gz, E:\sliced_output\train\subject_7_slice_42_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_7_slice_112_img.nii.gz, E:\sliced_output\train\subject_7_slice_112_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_7_slice_171_img.nii.gz, E:\sliced_output\train\subject_7_slice_171_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_7_slice_185_img.nii.gz, E:\sliced_output\train\subject_7_slice_185_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_8_slice_107_img.nii.gz, E:\sliced_output\train\subject_8_slice_107_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_8_slice_250_img.nii.gz, E:\sliced_output\train\subject_8_slice_250_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_8_slice_121_img.nii.gz, E:\sliced_output\train\subject_8_slice_121_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_8_slice_72_img.nii.gz, E:\sliced_output\train\subject_8_slice_72_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_8_slice_118_img.nii.gz, E:\sliced_output\train\subject_8_slice_118_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_8_slice_36_img.nii.gz, E:\sliced_output\train\subject_8_slice_36_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_8_slice_63_img.nii.gz, E:\sliced_output\train\subject_8_slice_63_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_8_slice_205_img.nii.gz, E:\sliced_output\train\subject_8_slice_205_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_8_slice_241_img.nii.gz, E:\sliced_output\train\subject_8_slice_241_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_8_slice_236_img.nii.gz, E:\sliced_output\train\subject_8_slice_236_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_8_slice_176_img.nii.gz, E:\sliced_output\train\subject_8_slice_176_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_8_slice_67_img.nii.gz, E:\sliced_output\train\subject_8_slice_67_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_9_slice_191_img.nii.gz, E:\sliced_output\train\subject_9_slice_191_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_9_slice_195_img.nii.gz, E:\sliced_output\train\subject_9_slice_195_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_9_slice_218_img.nii.gz, E:\sliced_output\train\subject_9_slice_218_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_9_slice_104_img.nii.gz, E:\sliced_output\train\subject_9_slice_104_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_9_slice_197_img.nii.gz, E:\sliced_output\train\subject_9_slice_197_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_9_slice_241_img.nii.gz, E:\sliced_output\train\subject_9_slice_241_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_9_slice_216_img.nii.gz, E:\sliced_output\train\subject_9_slice_216_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_9_slice_335_img.nii.gz, E:\sliced_output\train\subject_9_slice_335_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_9_slice_208_img.nii.gz, E:\sliced_output\train\subject_9_slice_208_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_9_slice_276_img.nii.gz, E:\sliced_output\train\subject_9_slice_276_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_9_slice_239_img.nii.gz, E:\sliced_output\train\subject_9_slice_239_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_9_slice_163_img.nii.gz, E:\sliced_output\train\subject_9_slice_163_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_10_slice_160_img.nii.gz, E:\sliced_output\train\subject_10_slice_160_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_10_slice_226_img.nii.gz, E:\sliced_output\train\subject_10_slice_226_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_10_slice_334_img.nii.gz, E:\sliced_output\train\subject_10_slice_334_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_10_slice_168_img.nii.gz, E:\sliced_output\train\subject_10_slice_168_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_10_slice_319_img.nii.gz, E:\sliced_output\train\subject_10_slice_319_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_10_slice_217_img.nii.gz, E:\sliced_output\train\subject_10_slice_217_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_10_slice_284_img.nii.gz, E:\sliced_output\train\subject_10_slice_284_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_10_slice_131_img.nii.gz, E:\sliced_output\train\subject_10_slice_131_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_10_slice_319_img.nii.gz, E:\sliced_output\train\subject_10_slice_319_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_10_slice_248_img.nii.gz, E:\sliced_output\train\subject_10_slice_248_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_10_slice_89_img.nii.gz, E:\sliced_output\train\subject_10_slice_89_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_10_slice_156_img.nii.gz, E:\sliced_output\train\subject_10_slice_156_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_11_slice_117_img.nii.gz, E:\sliced_output\train\subject_11_slice_117_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_11_slice_268_img.nii.gz, E:\sliced_output\train\subject_11_slice_268_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_11_slice_179_img.nii.gz, E:\sliced_output\train\subject_11_slice_179_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_11_slice_148_img.nii.gz, E:\sliced_output\train\subject_11_slice_148_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_11_slice_108_img.nii.gz, E:\sliced_output\train\subject_11_slice_108_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_11_slice_241_img.nii.gz, E:\sliced_output\train\subject_11_slice_241_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_11_slice_295_img.nii.gz, E:\sliced_output\train\subject_11_slice_295_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_11_slice_199_img.nii.gz, E:\sliced_output\train\subject_11_slice_199_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_11_slice_74_img.nii.gz, E:\sliced_output\train\subject_11_slice_74_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_11_slice_126_img.nii.gz, E:\sliced_output\train\subject_11_slice_126_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_11_slice_71_img.nii.gz, E:\sliced_output\train\subject_11_slice_71_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_11_slice_96_img.nii.gz, E:\sliced_output\train\subject_11_slice_96_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_12_slice_105_img.nii.gz, E:\sliced_output\train\subject_12_slice_105_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_12_slice_258_img.nii.gz, E:\sliced_output\train\subject_12_slice_258_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_12_slice_67_img.nii.gz, E:\sliced_output\train\subject_12_slice_67_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_12_slice_187_img.nii.gz, E:\sliced_output\train\subject_12_slice_187_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_12_slice_251_img.nii.gz, E:\sliced_output\train\subject_12_slice_251_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_12_slice_219_img.nii.gz, E:\sliced_output\train\subject_12_slice_219_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_12_slice_105_img.nii.gz, E:\sliced_output\train\subject_12_slice_105_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_12_slice_148_img.nii.gz, E:\sliced_output\train\subject_12_slice_148_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_12_slice_129_img.nii.gz, E:\sliced_output\train\subject_12_slice_129_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_12_slice_182_img.nii.gz, E:\sliced_output\train\subject_12_slice_182_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_12_slice_250_img.nii.gz, E:\sliced_output\train\subject_12_slice_250_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_12_slice_121_img.nii.gz, E:\sliced_output\train\subject_12_slice_121_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_13_slice_266_img.nii.gz, E:\sliced_output\train\subject_13_slice_266_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_13_slice_166_img.nii.gz, E:\sliced_output\train\subject_13_slice_166_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_13_slice_140_img.nii.gz, E:\sliced_output\train\subject_13_slice_140_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_13_slice_194_img.nii.gz, E:\sliced_output\train\subject_13_slice_194_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_13_slice_139_img.nii.gz, E:\sliced_output\train\subject_13_slice_139_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_13_slice_257_img.nii.gz, E:\sliced_output\train\subject_13_slice_257_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_13_slice_169_img.nii.gz, E:\sliced_output\train\subject_13_slice_169_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_13_slice_159_img.nii.gz, E:\sliced_output\train\subject_13_slice_159_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_13_slice_176_img.nii.gz, E:\sliced_output\train\subject_13_slice_176_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_13_slice_178_img.nii.gz, E:\sliced_output\train\subject_13_slice_178_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_13_slice_113_img.nii.gz, E:\sliced_output\train\subject_13_slice_113_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_13_slice_141_img.nii.gz, E:\sliced_output\train\subject_13_slice_141_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_14_slice_122_img.nii.gz, E:\sliced_output\train\subject_14_slice_122_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_14_slice_331_img.nii.gz, E:\sliced_output\train\subject_14_slice_331_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_14_slice_283_img.nii.gz, E:\sliced_output\train\subject_14_slice_283_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_14_slice_64_img.nii.gz, E:\sliced_output\train\subject_14_slice_64_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_14_slice_272_img.nii.gz, E:\sliced_output\train\subject_14_slice_272_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_14_slice_307_img.nii.gz, E:\sliced_output\train\subject_14_slice_307_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_14_slice_254_img.nii.gz, E:\sliced_output\train\subject_14_slice_254_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_14_slice_356_img.nii.gz, E:\sliced_output\train\subject_14_slice_356_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_14_slice_31_img.nii.gz, E:\sliced_output\train\subject_14_slice_31_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_14_slice_90_img.nii.gz, E:\sliced_output\train\subject_14_slice_90_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_14_slice_177_img.nii.gz, E:\sliced_output\train\subject_14_slice_177_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_14_slice_254_img.nii.gz, E:\sliced_output\train\subject_14_slice_254_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_15_slice_304_img.nii.gz, E:\sliced_output\train\subject_15_slice_304_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_15_slice_196_img.nii.gz, E:\sliced_output\train\subject_15_slice_196_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_15_slice_183_img.nii.gz, E:\sliced_output\train\subject_15_slice_183_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_15_slice_56_img.nii.gz, E:\sliced_output\train\subject_15_slice_56_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_15_slice_98_img.nii.gz, E:\sliced_output\train\subject_15_slice_98_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_15_slice_63_img.nii.gz, E:\sliced_output\train\subject_15_slice_63_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_15_slice_11_img.nii.gz, E:\sliced_output\train\subject_15_slice_11_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_15_slice_85_img.nii.gz, E:\sliced_output\train\subject_15_slice_85_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_15_slice_292_img.nii.gz, E:\sliced_output\train\subject_15_slice_292_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_15_slice_246_img.nii.gz, E:\sliced_output\train\subject_15_slice_246_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_15_slice_87_img.nii.gz, E:\sliced_output\train\subject_15_slice_87_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_15_slice_187_img.nii.gz, E:\sliced_output\train\subject_15_slice_187_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_16_slice_72_img.nii.gz, E:\sliced_output\train\subject_16_slice_72_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_16_slice_111_img.nii.gz, E:\sliced_output\train\subject_16_slice_111_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_16_slice_36_img.nii.gz, E:\sliced_output\train\subject_16_slice_36_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_16_slice_203_img.nii.gz, E:\sliced_output\train\subject_16_slice_203_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_16_slice_268_img.nii.gz, E:\sliced_output\train\subject_16_slice_268_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_16_slice_215_img.nii.gz, E:\sliced_output\train\subject_16_slice_215_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_16_slice_59_img.nii.gz, E:\sliced_output\train\subject_16_slice_59_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_16_slice_101_img.nii.gz, E:\sliced_output\train\subject_16_slice_101_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_16_slice_145_img.nii.gz, E:\sliced_output\train\subject_16_slice_145_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_16_slice_238_img.nii.gz, E:\sliced_output\train\subject_16_slice_238_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_16_slice_178_img.nii.gz, E:\sliced_output\train\subject_16_slice_178_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_16_slice_170_img.nii.gz, E:\sliced_output\train\subject_16_slice_170_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_17_slice_98_img.nii.gz, E:\sliced_output\train\subject_17_slice_98_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_17_slice_226_img.nii.gz, E:\sliced_output\train\subject_17_slice_226_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_17_slice_247_img.nii.gz, E:\sliced_output\train\subject_17_slice_247_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_17_slice_252_img.nii.gz, E:\sliced_output\train\subject_17_slice_252_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_17_slice_192_img.nii.gz, E:\sliced_output\train\subject_17_slice_192_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_17_slice_156_img.nii.gz, E:\sliced_output\train\subject_17_slice_156_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_17_slice_110_img.nii.gz, E:\sliced_output\train\subject_17_slice_110_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_17_slice_40_img.nii.gz, E:\sliced_output\train\subject_17_slice_40_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_17_slice_46_img.nii.gz, E:\sliced_output\train\subject_17_slice_46_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_17_slice_177_img.nii.gz, E:\sliced_output\train\subject_17_slice_177_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_17_slice_119_img.nii.gz, E:\sliced_output\train\subject_17_slice_119_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_17_slice_104_img.nii.gz, E:\sliced_output\train\subject_17_slice_104_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_18_slice_182_img.nii.gz, E:\sliced_output\train\subject_18_slice_182_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_18_slice_292_img.nii.gz, E:\sliced_output\train\subject_18_slice_292_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_18_slice_103_img.nii.gz, E:\sliced_output\train\subject_18_slice_103_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_18_slice_113_img.nii.gz, E:\sliced_output\train\subject_18_slice_113_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_18_slice_89_img.nii.gz, E:\sliced_output\train\subject_18_slice_89_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_18_slice_100_img.nii.gz, E:\sliced_output\train\subject_18_slice_100_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_18_slice_77_img.nii.gz, E:\sliced_output\train\subject_18_slice_77_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_18_slice_276_img.nii.gz, E:\sliced_output\train\subject_18_slice_276_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_18_slice_306_img.nii.gz, E:\sliced_output\train\subject_18_slice_306_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_18_slice_202_img.nii.gz, E:\sliced_output\train\subject_18_slice_202_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_18_slice_128_img.nii.gz, E:\sliced_output\train\subject_18_slice_128_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_18_slice_165_img.nii.gz, E:\sliced_output\train\subject_18_slice_165_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_19_slice_111_img.nii.gz, E:\sliced_output\train\subject_19_slice_111_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_19_slice_273_img.nii.gz, E:\sliced_output\train\subject_19_slice_273_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_19_slice_85_img.nii.gz, E:\sliced_output\train\subject_19_slice_85_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_19_slice_119_img.nii.gz, E:\sliced_output\train\subject_19_slice_119_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_19_slice_278_img.nii.gz, E:\sliced_output\train\subject_19_slice_278_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_19_slice_143_img.nii.gz, E:\sliced_output\train\subject_19_slice_143_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_19_slice_197_img.nii.gz, E:\sliced_output\train\subject_19_slice_197_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_19_slice_251_img.nii.gz, E:\sliced_output\train\subject_19_slice_251_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_19_slice_247_img.nii.gz, E:\sliced_output\train\subject_19_slice_247_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_19_slice_207_img.nii.gz, E:\sliced_output\train\subject_19_slice_207_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_19_slice_113_img.nii.gz, E:\sliced_output\train\subject_19_slice_113_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_19_slice_196_img.nii.gz, E:\sliced_output\train\subject_19_slice_196_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_20_slice_195_img.nii.gz, E:\sliced_output\train\subject_20_slice_195_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_20_slice_101_img.nii.gz, E:\sliced_output\train\subject_20_slice_101_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_20_slice_77_img.nii.gz, E:\sliced_output\train\subject_20_slice_77_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_20_slice_229_img.nii.gz, E:\sliced_output\train\subject_20_slice_229_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_20_slice_55_img.nii.gz, E:\sliced_output\train\subject_20_slice_55_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_20_slice_158_img.nii.gz, E:\sliced_output\train\subject_20_slice_158_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_20_slice_200_img.nii.gz, E:\sliced_output\train\subject_20_slice_200_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_20_slice_243_img.nii.gz, E:\sliced_output\train\subject_20_slice_243_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_20_slice_119_img.nii.gz, E:\sliced_output\train\subject_20_slice_119_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_20_slice_255_img.nii.gz, E:\sliced_output\train\subject_20_slice_255_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_20_slice_137_img.nii.gz, E:\sliced_output\train\subject_20_slice_137_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_20_slice_81_img.nii.gz, E:\sliced_output\train\subject_20_slice_81_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_21_slice_224_img.nii.gz, E:\sliced_output\train\subject_21_slice_224_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_21_slice_172_img.nii.gz, E:\sliced_output\train\subject_21_slice_172_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_21_slice_129_img.nii.gz, E:\sliced_output\train\subject_21_slice_129_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_21_slice_81_img.nii.gz, E:\sliced_output\train\subject_21_slice_81_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_21_slice_185_img.nii.gz, E:\sliced_output\train\subject_21_slice_185_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_21_slice_66_img.nii.gz, E:\sliced_output\train\subject_21_slice_66_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_21_slice_214_img.nii.gz, E:\sliced_output\train\subject_21_slice_214_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_21_slice_126_img.nii.gz, E:\sliced_output\train\subject_21_slice_126_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_21_slice_113_img.nii.gz, E:\sliced_output\train\subject_21_slice_113_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_21_slice_177_img.nii.gz, E:\sliced_output\train\subject_21_slice_177_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_21_slice_181_img.nii.gz, E:\sliced_output\train\subject_21_slice_181_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_21_slice_254_img.nii.gz, E:\sliced_output\train\subject_21_slice_254_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_22_slice_132_img.nii.gz, E:\sliced_output\train\subject_22_slice_132_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_22_slice_195_img.nii.gz, E:\sliced_output\train\subject_22_slice_195_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_22_slice_250_img.nii.gz, E:\sliced_output\train\subject_22_slice_250_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_22_slice_187_img.nii.gz, E:\sliced_output\train\subject_22_slice_187_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_22_slice_97_img.nii.gz, E:\sliced_output\train\subject_22_slice_97_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_22_slice_249_img.nii.gz, E:\sliced_output\train\subject_22_slice_249_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_22_slice_148_img.nii.gz, E:\sliced_output\train\subject_22_slice_148_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_22_slice_153_img.nii.gz, E:\sliced_output\train\subject_22_slice_153_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_22_slice_123_img.nii.gz, E:\sliced_output\train\subject_22_slice_123_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_22_slice_232_img.nii.gz, E:\sliced_output\train\subject_22_slice_232_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_22_slice_237_img.nii.gz, E:\sliced_output\train\subject_22_slice_237_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_22_slice_223_img.nii.gz, E:\sliced_output\train\subject_22_slice_223_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_23_slice_194_img.nii.gz, E:\sliced_output\train\subject_23_slice_194_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_23_slice_102_img.nii.gz, E:\sliced_output\train\subject_23_slice_102_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_23_slice_297_img.nii.gz, E:\sliced_output\train\subject_23_slice_297_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_23_slice_280_img.nii.gz, E:\sliced_output\train\subject_23_slice_280_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_23_slice_81_img.nii.gz, E:\sliced_output\train\subject_23_slice_81_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_23_slice_86_img.nii.gz, E:\sliced_output\train\subject_23_slice_86_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_23_slice_139_img.nii.gz, E:\sliced_output\train\subject_23_slice_139_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_23_slice_135_img.nii.gz, E:\sliced_output\train\subject_23_slice_135_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_23_slice_228_img.nii.gz, E:\sliced_output\train\subject_23_slice_228_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_23_slice_254_img.nii.gz, E:\sliced_output\train\subject_23_slice_254_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_23_slice_245_img.nii.gz, E:\sliced_output\train\subject_23_slice_245_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_23_slice_205_img.nii.gz, E:\sliced_output\train\subject_23_slice_205_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_24_slice_99_img.nii.gz, E:\sliced_output\train\subject_24_slice_99_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_24_slice_158_img.nii.gz, E:\sliced_output\train\subject_24_slice_158_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_24_slice_289_img.nii.gz, E:\sliced_output\train\subject_24_slice_289_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_24_slice_211_img.nii.gz, E:\sliced_output\train\subject_24_slice_211_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_24_slice_289_img.nii.gz, E:\sliced_output\train\subject_24_slice_289_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_24_slice_63_img.nii.gz, E:\sliced_output\train\subject_24_slice_63_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_24_slice_282_img.nii.gz, E:\sliced_output\train\subject_24_slice_282_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_24_slice_272_img.nii.gz, E:\sliced_output\train\subject_24_slice_272_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_24_slice_124_img.nii.gz, E:\sliced_output\train\subject_24_slice_124_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_24_slice_189_img.nii.gz, E:\sliced_output\train\subject_24_slice_189_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_24_slice_226_img.nii.gz, E:\sliced_output\train\subject_24_slice_226_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_24_slice_66_img.nii.gz, E:\sliced_output\train\subject_24_slice_66_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_25_slice_47_img.nii.gz, E:\sliced_output\train\subject_25_slice_47_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_25_slice_49_img.nii.gz, E:\sliced_output\train\subject_25_slice_49_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_25_slice_259_img.nii.gz, E:\sliced_output\train\subject_25_slice_259_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_25_slice_112_img.nii.gz, E:\sliced_output\train\subject_25_slice_112_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_25_slice_215_img.nii.gz, E:\sliced_output\train\subject_25_slice_215_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_25_slice_240_img.nii.gz, E:\sliced_output\train\subject_25_slice_240_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_25_slice_220_img.nii.gz, E:\sliced_output\train\subject_25_slice_220_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_25_slice_61_img.nii.gz, E:\sliced_output\train\subject_25_slice_61_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_25_slice_131_img.nii.gz, E:\sliced_output\train\subject_25_slice_131_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_25_slice_55_img.nii.gz, E:\sliced_output\train\subject_25_slice_55_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_25_slice_11_img.nii.gz, E:\sliced_output\train\subject_25_slice_11_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_25_slice_104_img.nii.gz, E:\sliced_output\train\subject_25_slice_104_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_26_slice_250_img.nii.gz, E:\sliced_output\train\subject_26_slice_250_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_26_slice_107_img.nii.gz, E:\sliced_output\train\subject_26_slice_107_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_26_slice_169_img.nii.gz, E:\sliced_output\train\subject_26_slice_169_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_26_slice_54_img.nii.gz, E:\sliced_output\train\subject_26_slice_54_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_26_slice_191_img.nii.gz, E:\sliced_output\train\subject_26_slice_191_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_26_slice_195_img.nii.gz, E:\sliced_output\train\subject_26_slice_195_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_26_slice_79_img.nii.gz, E:\sliced_output\train\subject_26_slice_79_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_26_slice_194_img.nii.gz, E:\sliced_output\train\subject_26_slice_194_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_26_slice_195_img.nii.gz, E:\sliced_output\train\subject_26_slice_195_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_26_slice_252_img.nii.gz, E:\sliced_output\train\subject_26_slice_252_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_26_slice_161_img.nii.gz, E:\sliced_output\train\subject_26_slice_161_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_26_slice_63_img.nii.gz, E:\sliced_output\train\subject_26_slice_63_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_27_slice_211_img.nii.gz, E:\sliced_output\train\subject_27_slice_211_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_27_slice_149_img.nii.gz, E:\sliced_output\train\subject_27_slice_149_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_27_slice_267_img.nii.gz, E:\sliced_output\train\subject_27_slice_267_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_27_slice_153_img.nii.gz, E:\sliced_output\train\subject_27_slice_153_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_27_slice_243_img.nii.gz, E:\sliced_output\train\subject_27_slice_243_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_27_slice_268_img.nii.gz, E:\sliced_output\train\subject_27_slice_268_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_27_slice_186_img.nii.gz, E:\sliced_output\train\subject_27_slice_186_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_27_slice_244_img.nii.gz, E:\sliced_output\train\subject_27_slice_244_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_27_slice_140_img.nii.gz, E:\sliced_output\train\subject_27_slice_140_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_27_slice_249_img.nii.gz, E:\sliced_output\train\subject_27_slice_249_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_27_slice_124_img.nii.gz, E:\sliced_output\train\subject_27_slice_124_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_27_slice_181_img.nii.gz, E:\sliced_output\train\subject_27_slice_181_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_28_slice_289_img.nii.gz, E:\sliced_output\train\subject_28_slice_289_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_28_slice_198_img.nii.gz, E:\sliced_output\train\subject_28_slice_198_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_28_slice_274_img.nii.gz, E:\sliced_output\train\subject_28_slice_274_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_28_slice_223_img.nii.gz, E:\sliced_output\train\subject_28_slice_223_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_28_slice_123_img.nii.gz, E:\sliced_output\train\subject_28_slice_123_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_28_slice_298_img.nii.gz, E:\sliced_output\train\subject_28_slice_298_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_28_slice_271_img.nii.gz, E:\sliced_output\train\subject_28_slice_271_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_28_slice_232_img.nii.gz, E:\sliced_output\train\subject_28_slice_232_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_28_slice_327_img.nii.gz, E:\sliced_output\train\subject_28_slice_327_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_28_slice_291_img.nii.gz, E:\sliced_output\train\subject_28_slice_291_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_28_slice_242_img.nii.gz, E:\sliced_output\train\subject_28_slice_242_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_28_slice_325_img.nii.gz, E:\sliced_output\train\subject_28_slice_325_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_29_slice_79_img.nii.gz, E:\sliced_output\train\subject_29_slice_79_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_29_slice_75_img.nii.gz, E:\sliced_output\train\subject_29_slice_75_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_29_slice_275_img.nii.gz, E:\sliced_output\train\subject_29_slice_275_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_29_slice_205_img.nii.gz, E:\sliced_output\train\subject_29_slice_205_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_29_slice_286_img.nii.gz, E:\sliced_output\train\subject_29_slice_286_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_29_slice_274_img.nii.gz, E:\sliced_output\train\subject_29_slice_274_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_29_slice_110_img.nii.gz, E:\sliced_output\train\subject_29_slice_110_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_29_slice_57_img.nii.gz, E:\sliced_output\train\subject_29_slice_57_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_29_slice_102_img.nii.gz, E:\sliced_output\train\subject_29_slice_102_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_29_slice_147_img.nii.gz, E:\sliced_output\train\subject_29_slice_147_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_29_slice_181_img.nii.gz, E:\sliced_output\train\subject_29_slice_181_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_29_slice_222_img.nii.gz, E:\sliced_output\train\subject_29_slice_222_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_30_slice_191_img.nii.gz, E:\sliced_output\train\subject_30_slice_191_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_30_slice_121_img.nii.gz, E:\sliced_output\train\subject_30_slice_121_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_30_slice_65_img.nii.gz, E:\sliced_output\train\subject_30_slice_65_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_30_slice_38_img.nii.gz, E:\sliced_output\train\subject_30_slice_38_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_30_slice_208_img.nii.gz, E:\sliced_output\train\subject_30_slice_208_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_30_slice_209_img.nii.gz, E:\sliced_output\train\subject_30_slice_209_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_30_slice_89_img.nii.gz, E:\sliced_output\train\subject_30_slice_89_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_30_slice_204_img.nii.gz, E:\sliced_output\train\subject_30_slice_204_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_30_slice_81_img.nii.gz, E:\sliced_output\train\subject_30_slice_81_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_30_slice_262_img.nii.gz, E:\sliced_output\train\subject_30_slice_262_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_30_slice_106_img.nii.gz, E:\sliced_output\train\subject_30_slice_106_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_30_slice_156_img.nii.gz, E:\sliced_output\train\subject_30_slice_156_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_31_slice_125_img.nii.gz, E:\sliced_output\train\subject_31_slice_125_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_31_slice_182_img.nii.gz, E:\sliced_output\train\subject_31_slice_182_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_31_slice_298_img.nii.gz, E:\sliced_output\train\subject_31_slice_298_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_31_slice_121_img.nii.gz, E:\sliced_output\train\subject_31_slice_121_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_31_slice_112_img.nii.gz, E:\sliced_output\train\subject_31_slice_112_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_31_slice_44_img.nii.gz, E:\sliced_output\train\subject_31_slice_44_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_31_slice_96_img.nii.gz, E:\sliced_output\train\subject_31_slice_96_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_31_slice_257_img.nii.gz, E:\sliced_output\train\subject_31_slice_257_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_31_slice_293_img.nii.gz, E:\sliced_output\train\subject_31_slice_293_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_31_slice_268_img.nii.gz, E:\sliced_output\train\subject_31_slice_268_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_31_slice_133_img.nii.gz, E:\sliced_output\train\subject_31_slice_133_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_31_slice_148_img.nii.gz, E:\sliced_output\train\subject_31_slice_148_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_32_slice_191_img.nii.gz, E:\sliced_output\train\subject_32_slice_191_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_32_slice_121_img.nii.gz, E:\sliced_output\train\subject_32_slice_121_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_32_slice_287_img.nii.gz, E:\sliced_output\train\subject_32_slice_287_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_32_slice_99_img.nii.gz, E:\sliced_output\train\subject_32_slice_99_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_32_slice_238_img.nii.gz, E:\sliced_output\train\subject_32_slice_238_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_32_slice_158_img.nii.gz, E:\sliced_output\train\subject_32_slice_158_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_32_slice_149_img.nii.gz, E:\sliced_output\train\subject_32_slice_149_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_32_slice_121_img.nii.gz, E:\sliced_output\train\subject_32_slice_121_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_32_slice_167_img.nii.gz, E:\sliced_output\train\subject_32_slice_167_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_32_slice_300_img.nii.gz, E:\sliced_output\train\subject_32_slice_300_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_32_slice_16_img.nii.gz, E:\sliced_output\train\subject_32_slice_16_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_32_slice_95_img.nii.gz, E:\sliced_output\train\subject_32_slice_95_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_33_slice_213_img.nii.gz, E:\sliced_output\train\subject_33_slice_213_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_33_slice_120_img.nii.gz, E:\sliced_output\train\subject_33_slice_120_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_33_slice_170_img.nii.gz, E:\sliced_output\train\subject_33_slice_170_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_33_slice_231_img.nii.gz, E:\sliced_output\train\subject_33_slice_231_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_33_slice_330_img.nii.gz, E:\sliced_output\train\subject_33_slice_330_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_33_slice_344_img.nii.gz, E:\sliced_output\train\subject_33_slice_344_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_33_slice_202_img.nii.gz, E:\sliced_output\train\subject_33_slice_202_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_33_slice_159_img.nii.gz, E:\sliced_output\train\subject_33_slice_159_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_33_slice_96_img.nii.gz, E:\sliced_output\train\subject_33_slice_96_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_33_slice_224_img.nii.gz, E:\sliced_output\train\subject_33_slice_224_lbl.nii.gz
# ...
# Saved: E:\sliced_output\train\subject_788_slice_235_img.nii.gz, E:\sliced_output\train\subject_788_slice_235_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_789_slice_194_img.nii.gz, E:\sliced_output\train\subject_789_slice_194_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_789_slice_165_img.nii.gz, E:\sliced_output\train\subject_789_slice_165_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_789_slice_294_img.nii.gz, E:\sliced_output\train\subject_789_slice_294_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_789_slice_295_img.nii.gz, E:\sliced_output\train\subject_789_slice_295_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_789_slice_252_img.nii.gz, E:\sliced_output\train\subject_789_slice_252_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_789_slice_174_img.nii.gz, E:\sliced_output\train\subject_789_slice_174_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_789_slice_112_img.nii.gz, E:\sliced_output\train\subject_789_slice_112_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_789_slice_211_img.nii.gz, E:\sliced_output\train\subject_789_slice_211_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_789_slice_189_img.nii.gz, E:\sliced_output\train\subject_789_slice_189_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_789_slice_208_img.nii.gz, E:\sliced_output\train\subject_789_slice_208_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_789_slice_212_img.nii.gz, E:\sliced_output\train\subject_789_slice_212_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_789_slice_79_img.nii.gz, E:\sliced_output\train\subject_789_slice_79_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_790_slice_177_img.nii.gz, E:\sliced_output\train\subject_790_slice_177_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_790_slice_335_img.nii.gz, E:\sliced_output\train\subject_790_slice_335_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_790_slice_218_img.nii.gz, E:\sliced_output\train\subject_790_slice_218_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_790_slice_116_img.nii.gz, E:\sliced_output\train\subject_790_slice_116_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_790_slice_163_img.nii.gz, E:\sliced_output\train\subject_790_slice_163_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_790_slice_230_img.nii.gz, E:\sliced_output\train\subject_790_slice_230_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_790_slice_111_img.nii.gz, E:\sliced_output\train\subject_790_slice_111_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_790_slice_261_img.nii.gz, E:\sliced_output\train\subject_790_slice_261_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_790_slice_140_img.nii.gz, E:\sliced_output\train\subject_790_slice_140_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_790_slice_112_img.nii.gz, E:\sliced_output\train\subject_790_slice_112_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_790_slice_279_img.nii.gz, E:\sliced_output\train\subject_790_slice_279_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_790_slice_327_img.nii.gz, E:\sliced_output\train\subject_790_slice_327_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_791_slice_53_img.nii.gz, E:\sliced_output\train\subject_791_slice_53_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_791_slice_205_img.nii.gz, E:\sliced_output\train\subject_791_slice_205_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_791_slice_124_img.nii.gz, E:\sliced_output\train\subject_791_slice_124_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_791_slice_31_img.nii.gz, E:\sliced_output\train\subject_791_slice_31_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_791_slice_127_img.nii.gz, E:\sliced_output\train\subject_791_slice_127_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_791_slice_10_img.nii.gz, E:\sliced_output\train\subject_791_slice_10_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_791_slice_200_img.nii.gz, E:\sliced_output\train\subject_791_slice_200_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_791_slice_204_img.nii.gz, E:\sliced_output\train\subject_791_slice_204_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_791_slice_43_img.nii.gz, E:\sliced_output\train\subject_791_slice_43_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_791_slice_90_img.nii.gz, E:\sliced_output\train\subject_791_slice_90_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_791_slice_99_img.nii.gz, E:\sliced_output\train\subject_791_slice_99_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_791_slice_217_img.nii.gz, E:\sliced_output\train\subject_791_slice_217_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_792_slice_73_img.nii.gz, E:\sliced_output\train\subject_792_slice_73_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_792_slice_52_img.nii.gz, E:\sliced_output\train\subject_792_slice_52_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_792_slice_108_img.nii.gz, E:\sliced_output\train\subject_792_slice_108_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_792_slice_110_img.nii.gz, E:\sliced_output\train\subject_792_slice_110_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_792_slice_250_img.nii.gz, E:\sliced_output\train\subject_792_slice_250_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_792_slice_230_img.nii.gz, E:\sliced_output\train\subject_792_slice_230_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_792_slice_130_img.nii.gz, E:\sliced_output\train\subject_792_slice_130_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_792_slice_217_img.nii.gz, E:\sliced_output\train\subject_792_slice_217_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_792_slice_159_img.nii.gz, E:\sliced_output\train\subject_792_slice_159_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_792_slice_108_img.nii.gz, E:\sliced_output\train\subject_792_slice_108_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_792_slice_217_img.nii.gz, E:\sliced_output\train\subject_792_slice_217_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_792_slice_65_img.nii.gz, E:\sliced_output\train\subject_792_slice_65_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_793_slice_154_img.nii.gz, E:\sliced_output\train\subject_793_slice_154_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_793_slice_247_img.nii.gz, E:\sliced_output\train\subject_793_slice_247_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_793_slice_204_img.nii.gz, E:\sliced_output\train\subject_793_slice_204_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_793_slice_322_img.nii.gz, E:\sliced_output\train\subject_793_slice_322_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_793_slice_52_img.nii.gz, E:\sliced_output\train\subject_793_slice_52_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_793_slice_134_img.nii.gz, E:\sliced_output\train\subject_793_slice_134_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_793_slice_43_img.nii.gz, E:\sliced_output\train\subject_793_slice_43_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_793_slice_330_img.nii.gz, E:\sliced_output\train\subject_793_slice_330_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_793_slice_153_img.nii.gz, E:\sliced_output\train\subject_793_slice_153_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_793_slice_289_img.nii.gz, E:\sliced_output\train\subject_793_slice_289_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_793_slice_214_img.nii.gz, E:\sliced_output\train\subject_793_slice_214_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_793_slice_129_img.nii.gz, E:\sliced_output\train\subject_793_slice_129_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_794_slice_277_img.nii.gz, E:\sliced_output\train\subject_794_slice_277_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_794_slice_178_img.nii.gz, E:\sliced_output\train\subject_794_slice_178_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_794_slice_119_img.nii.gz, E:\sliced_output\train\subject_794_slice_119_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_794_slice_306_img.nii.gz, E:\sliced_output\train\subject_794_slice_306_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_794_slice_124_img.nii.gz, E:\sliced_output\train\subject_794_slice_124_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_794_slice_231_img.nii.gz, E:\sliced_output\train\subject_794_slice_231_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_794_slice_159_img.nii.gz, E:\sliced_output\train\subject_794_slice_159_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_794_slice_156_img.nii.gz, E:\sliced_output\train\subject_794_slice_156_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_794_slice_313_img.nii.gz, E:\sliced_output\train\subject_794_slice_313_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_794_slice_336_img.nii.gz, E:\sliced_output\train\subject_794_slice_336_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_794_slice_243_img.nii.gz, E:\sliced_output\train\subject_794_slice_243_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_794_slice_181_img.nii.gz, E:\sliced_output\train\subject_794_slice_181_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_795_slice_203_img.nii.gz, E:\sliced_output\train\subject_795_slice_203_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_795_slice_65_img.nii.gz, E:\sliced_output\train\subject_795_slice_65_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_795_slice_161_img.nii.gz, E:\sliced_output\train\subject_795_slice_161_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_795_slice_77_img.nii.gz, E:\sliced_output\train\subject_795_slice_77_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_795_slice_35_img.nii.gz, E:\sliced_output\train\subject_795_slice_35_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_795_slice_84_img.nii.gz, E:\sliced_output\train\subject_795_slice_84_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_795_slice_28_img.nii.gz, E:\sliced_output\train\subject_795_slice_28_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_795_slice_144_img.nii.gz, E:\sliced_output\train\subject_795_slice_144_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_795_slice_155_img.nii.gz, E:\sliced_output\train\subject_795_slice_155_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_795_slice_143_img.nii.gz, E:\sliced_output\train\subject_795_slice_143_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_795_slice_248_img.nii.gz, E:\sliced_output\train\subject_795_slice_248_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_795_slice_228_img.nii.gz, E:\sliced_output\train\subject_795_slice_228_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_796_slice_123_img.nii.gz, E:\sliced_output\train\subject_796_slice_123_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_796_slice_240_img.nii.gz, E:\sliced_output\train\subject_796_slice_240_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_796_slice_71_img.nii.gz, E:\sliced_output\train\subject_796_slice_71_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_796_slice_107_img.nii.gz, E:\sliced_output\train\subject_796_slice_107_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_796_slice_91_img.nii.gz, E:\sliced_output\train\subject_796_slice_91_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_796_slice_251_img.nii.gz, E:\sliced_output\train\subject_796_slice_251_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_796_slice_144_img.nii.gz, E:\sliced_output\train\subject_796_slice_144_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_796_slice_168_img.nii.gz, E:\sliced_output\train\subject_796_slice_168_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_796_slice_205_img.nii.gz, E:\sliced_output\train\subject_796_slice_205_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_796_slice_121_img.nii.gz, E:\sliced_output\train\subject_796_slice_121_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_796_slice_109_img.nii.gz, E:\sliced_output\train\subject_796_slice_109_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_796_slice_118_img.nii.gz, E:\sliced_output\train\subject_796_slice_118_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_797_slice_189_img.nii.gz, E:\sliced_output\train\subject_797_slice_189_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_797_slice_52_img.nii.gz, E:\sliced_output\train\subject_797_slice_52_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_797_slice_0_img.nii.gz, E:\sliced_output\train\subject_797_slice_0_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_797_slice_117_img.nii.gz, E:\sliced_output\train\subject_797_slice_117_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_797_slice_214_img.nii.gz, E:\sliced_output\train\subject_797_slice_214_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_797_slice_61_img.nii.gz, E:\sliced_output\train\subject_797_slice_61_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_797_slice_81_img.nii.gz, E:\sliced_output\train\subject_797_slice_81_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_797_slice_290_img.nii.gz, E:\sliced_output\train\subject_797_slice_290_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_797_slice_265_img.nii.gz, E:\sliced_output\train\subject_797_slice_265_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_797_slice_154_img.nii.gz, E:\sliced_output\train\subject_797_slice_154_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_797_slice_134_img.nii.gz, E:\sliced_output\train\subject_797_slice_134_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_797_slice_159_img.nii.gz, E:\sliced_output\train\subject_797_slice_159_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_798_slice_210_img.nii.gz, E:\sliced_output\train\subject_798_slice_210_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_798_slice_175_img.nii.gz, E:\sliced_output\train\subject_798_slice_175_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_798_slice_252_img.nii.gz, E:\sliced_output\train\subject_798_slice_252_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_798_slice_246_img.nii.gz, E:\sliced_output\train\subject_798_slice_246_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_798_slice_126_img.nii.gz, E:\sliced_output\train\subject_798_slice_126_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_798_slice_272_img.nii.gz, E:\sliced_output\train\subject_798_slice_272_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_798_slice_122_img.nii.gz, E:\sliced_output\train\subject_798_slice_122_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_798_slice_113_img.nii.gz, E:\sliced_output\train\subject_798_slice_113_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_798_slice_124_img.nii.gz, E:\sliced_output\train\subject_798_slice_124_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_798_slice_251_img.nii.gz, E:\sliced_output\train\subject_798_slice_251_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_798_slice_156_img.nii.gz, E:\sliced_output\train\subject_798_slice_156_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_798_slice_202_img.nii.gz, E:\sliced_output\train\subject_798_slice_202_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_799_slice_95_img.nii.gz, E:\sliced_output\train\subject_799_slice_95_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_799_slice_67_img.nii.gz, E:\sliced_output\train\subject_799_slice_67_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_799_slice_255_img.nii.gz, E:\sliced_output\train\subject_799_slice_255_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_799_slice_254_img.nii.gz, E:\sliced_output\train\subject_799_slice_254_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_799_slice_118_img.nii.gz, E:\sliced_output\train\subject_799_slice_118_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_799_slice_222_img.nii.gz, E:\sliced_output\train\subject_799_slice_222_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_799_slice_107_img.nii.gz, E:\sliced_output\train\subject_799_slice_107_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_799_slice_225_img.nii.gz, E:\sliced_output\train\subject_799_slice_225_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_799_slice_102_img.nii.gz, E:\sliced_output\train\subject_799_slice_102_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_799_slice_144_img.nii.gz, E:\sliced_output\train\subject_799_slice_144_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_799_slice_41_img.nii.gz, E:\sliced_output\train\subject_799_slice_41_lbl.nii.gz
# Saved: E:\sliced_output\train\subject_799_slice_214_img.nii.gz, E:\sliced_output\train\subject_799_slice_214_lbl.nii.gz

# %%
# Suppose you have something like:
image_set = 'val'
file_paths = glob(os.path.join(r'E:\sliced_output', image_set, "*.nii.gz"))
image_paths, label_paths = [], []
for path in file_paths:
    print(path.split("\\")[-1][-10:-7])
    # if path.split("\\")[-1][-10:-7] == 'lbl':
    #     label_paths.append(path)
#     else:
#         image_paths.append(path)

# image_paths, label_paths = sorted(image_paths), sorted(label_paths)
# slice_dicts = [
#     {"image": image_path, "label": label_path}
#     for image_path, label_path in zip(image_paths, label_paths)
# ]
# Out:
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl
# img
# lbl

# %%
if image_set == 'train':
    slice_transform = slice_transform_train
else:
    slice_transform = slice_transform_valid
    
class Slices2DDataset(Dataset):
    def __init__(self, data, transform=None):
        """
        data_dicts: list of {"image": <path>, "label": <path>}
        slice_transform: optional transform pipeline (e.g. LoadImaged, etc.)
        """
        self.data_dicts = data
        self.slice_transform = transform

    def __len__(self):
        return len(self.data_dicts)

    def __getitem__(self, idx):
        d = self.data_dicts[idx]
        # If you want to load the data and transform it:
        if self.slice_transform is not None:
            d = self.slice_transform(d)
        return d

# %%
for _, data_dict in enumerate(slice_dicts):
    # ---------------------------------------------------------
    # 1) Load & apply 3D transforms (e.g. LoadImaged, Spacingd, etc.)
    # ---------------------------------------------------------
    img_nii = nib.load(data_dict['image'])
    processed_3d = slice_transform(data_dict)

# %%
dataset = Slices2DDataset(data=slice_dicts, transform=slice_transform)
from torch.utils.data import DataLoader
valid_loader = DataLoader(
    dataset,
    32,
    False,
    num_workers=0,
    pin_memory=True,
)

# %%
total_step = len(valid_loader)
train_iterator = iter(valid_loader)

for step in range(total_step):
    data_dict = next(train_iterator)
    samples = data_dict["image"]
    print(samples.shape)  # should be [B, C, H, W]
# Out:
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_101_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_0_slice_101_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_116_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_0_slice_116_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_138_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_0_slice_138_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_143_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_0_slice_143_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_185_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_0_slice_185_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_220_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_0_slice_220_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_242_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_0_slice_242_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_255_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_0_slice_255_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_46_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_10_slice_12_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_46_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_10_slice_13_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_84_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_10_slice_19_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_84_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_10_slice_48_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_95_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_10_slice_69_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_0_slice_95_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_10_slice_82_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_124_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_10_slice_88_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_124_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_11_slice_30_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_12_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_11_slice_67_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_13_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_11_slice_81_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_175_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_12_slice_21_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_175_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_12_slice_52_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_186_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_12_slice_59_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_186_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_12_slice_70_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_19_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_12_slice_72_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_263_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_12_slice_89_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_263_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_13_slice_92_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_268_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_13_slice_98_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_268_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_14_slice_62_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_48_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_15_slice_48_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_69_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_15_slice_75_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_82_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_16_slice_86_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_10_slice_88_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_18_slice_39_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_101_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_18_slice_48_lbl.nii.gz'}
# torch.Size([32, 1, 192, 192])
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_101_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_19_slice_87_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_106_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_19_slice_92_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_106_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_19_slice_99_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_130_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_1_slice_100_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_130_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_1_slice_103_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_140_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_1_slice_136_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_140_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_1_slice_161_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_183_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_1_slice_172_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_183_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_1_slice_177_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_184_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_1_slice_204_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_184_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_1_slice_207_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_210_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_1_slice_241_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_210_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_1_slice_258_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_238_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_1_slice_265_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_238_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_20_slice_40_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_255_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_20_slice_51_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_255_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_20_slice_69_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_30_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_20_slice_72_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_67_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_20_slice_98_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_11_slice_81_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_21_slice_66_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_128_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_21_slice_93_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_128_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_22_slice_60_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_144_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_22_slice_66_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_144_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_22_slice_85_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_167_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_22_slice_92_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_167_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_23_slice_10_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_21_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_23_slice_94_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_223_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_24_slice_62_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_223_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_24_slice_64_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_229_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_24_slice_65_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_229_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_24_slice_66_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_251_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_24_slice_91_lbl.nii.gz'}
# torch.Size([32, 1, 192, 192])
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_251_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_25_slice_24_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_52_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_25_slice_58_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_59_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_25_slice_66_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_70_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_25_slice_77_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_72_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_26_slice_46_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_12_slice_89_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_26_slice_82_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_101_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_26_slice_99_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_101_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_27_slice_67_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_108_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_28_slice_18_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_108_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_28_slice_32_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_114_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_28_slice_84_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_114_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_28_slice_91_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_135_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_28_slice_99_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_135_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_2_slice_123_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_156_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_2_slice_141_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_156_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_2_slice_158_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_206_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_2_slice_173_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_206_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_2_slice_199_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_234_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_2_slice_205_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_234_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_2_slice_272_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_249_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_2_slice_274_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_249_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_2_slice_293_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_305_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_2_slice_299_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_305_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_31_slice_44_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_318_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_31_slice_53_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_318_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_31_slice_69_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_92_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_32_slice_42_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_13_slice_98_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_32_slice_64_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_140_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_32_slice_88_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_140_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_32_slice_95_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_145_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_33_slice_35_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_145_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_33_slice_82_lbl.nii.gz'}
# torch.Size([32, 1, 192, 192])
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_158_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_33_slice_83_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_158_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_35_slice_31_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_177_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_35_slice_47_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_177_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_35_slice_60_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_179_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_35_slice_67_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_179_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_35_slice_89_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_183_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_36_slice_62_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_183_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_36_slice_79_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_224_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_36_slice_84_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_224_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_37_slice_61_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_235_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_37_slice_81_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_235_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_37_slice_93_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_250_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_3_slice_102_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_250_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_3_slice_130_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_279_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_3_slice_152_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_279_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_3_slice_163_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_14_slice_62_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_3_slice_177_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_123_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_3_slice_220_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_123_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_4_slice_139_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_153_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_4_slice_153_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_153_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_4_slice_161_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_155_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_4_slice_175_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_155_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_4_slice_197_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_177_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_4_slice_213_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_177_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_4_slice_236_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_187_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_4_slice_240_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_187_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_4_slice_248_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_211_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_5_slice_119_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_211_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_5_slice_120_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_241_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_5_slice_145_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_241_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_5_slice_171_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_247_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_5_slice_187_lbl.nii.gz'}
# torch.Size([32, 1, 192, 192])
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_247_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_5_slice_193_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_268_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_5_slice_203_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_268_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_5_slice_215_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_305_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_5_slice_221_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_305_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_5_slice_246_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_48_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_6_slice_100_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_15_slice_75_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_6_slice_129_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_107_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_6_slice_145_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_107_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_6_slice_162_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_116_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_6_slice_196_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_116_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_6_slice_199_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_162_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_6_slice_251_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_162_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_6_slice_255_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_189_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_6_slice_267_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_189_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_7_slice_166_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_195_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_7_slice_175_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_195_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_7_slice_197_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_206_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_7_slice_198_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_206_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_7_slice_214_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_215_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_7_slice_231_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_215_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_7_slice_240_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_237_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_7_slice_284_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_237_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_8_slice_109_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_245_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_8_slice_128_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_245_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_8_slice_146_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_309_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_8_slice_150_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_309_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_8_slice_161_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_16_slice_86_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_8_slice_183_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_164_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_8_slice_222_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_164_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_8_slice_234_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_213_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_9_slice_100_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_213_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_9_slice_105_lbl.nii.gz'}
# torch.Size([32, 1, 192, 192])
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_218_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_9_slice_109_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_218_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_9_slice_152_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_227_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_9_slice_155_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_227_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_9_slice_236_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_240_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_9_slice_237_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_240_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_9_slice_247_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_265_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_9_slice_248_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_265_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_9_slice_275_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_281_img.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_9_slice_281_lbl.nii.gz'}
# {'image': 'E:\\sliced_output\\val\\subject_17_slice_281_lbl.nii.gz', 'label': 'E:\\sliced_output\\val\\subject_9_slice_286_lbl.nii.gz'}
# torch.Size([10, 1, 192, 192])
